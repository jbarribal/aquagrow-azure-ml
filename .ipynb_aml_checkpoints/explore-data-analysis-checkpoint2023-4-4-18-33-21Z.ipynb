# %%
from azure.ai.ml import MLClient
from azure.identity import DefaultAzureCredential
from azure.ai.ml.entities import Data
from azure.ai.ml.constants import AssetTypes

# authenticate
credential = DefaultAzureCredential()

# Get a handle to the workspace
ml_client = MLClient(
    credential=credential,
    subscription_id="abb3353d-14ab-4405-8fec-2be226eecc91",
    resource_group_name="BARRIBAL.JOSHUAGEORGE-rg",
    workspace_name="aquagrow",
)

# %%
from azure.ai.ml.entities import Data
from azure.ai.ml.constants import AssetTypes
import time

# update the 'my_path' variable to match the location of where you downloaded the data on your
# local filesystem

data_path = "./data/meanIntervalData.csv"
# set the version number of the data asset to the current UTC time
v1 = time.strftime("%Y.%m.%d.%H%M%S", time.gmtime())


mean_data = Data(
    name="means-dataset",
    version=v1,
    description="Aquagrow mean data set",
    path=data_path,
    type=AssetTypes.URI_FILE,
)

# create data asset
ml_client.data.create_or_update(mean_data)

print(f"Data asset created. Name: {mean_data.name}, version: {mean_data.version}")
# Out:
# Data asset created. Name: means-dataset, version: 2023.05.04.182852

# %%
from azure.ai.ml.entities import Data
from azure.ai.ml.constants import AssetTypes
import time

# update the 'my_path' variable to match the location of where you downloaded the data on your
# local filesystem

weight_path = "./data/lettuceWeights.csv"
# set the version number of the data asset to the current UTC time
v1 = time.strftime("%Y.%m.%d.%H%M%S", time.gmtime())


weight_data = Data(
    name="weights-dataset",
    version=v1,
    description="Aquagrow observed lettuce weights",
    path=weight_path,
    type=AssetTypes.URI_FILE,
)

# create data asset
ml_client.data.create_or_update(weight_data)

print(f"Data asset created. Name: {weight_data.name}, version: {weight_data.version}")
# Out:
# Data asset created. Name: weights-dataset, version: 2023.05.04.182901

# %%
print(ml_client.data.list())
# Out:
# <iterator object azure.core.paging.ItemPaged at 0x7fdd08a829b0>

# %%
# %pip install -U azureml-fsspec

# %%
import pandas as pd

# get a handle of the data asset and print the URI
mean_asset = ml_client.data.get(name="means-dataset", version=v1)
print(f"Data asset URI: {mean_asset.path}")

weight_asset = ml_client.data.get(name="weights-dataset", version=v1)
print(f"Data asset URI: {weight_asset.path}")

# read into pandas - note that you will see 2 headers in your data frame - that is ok, for now

mean_dataset = pd.read_csv(mean_asset.path)
mean_dataset.head()

weight_dataset = pd.read_csv(weight_asset.path)
weight_dataset.head()
# Out:
# ---------------------------------------------------------------------------
# ResourceNotFoundError                     Traceback (most recent call last)
# Cell In[21], line 4
#       1 import pandas as pd
#       3 # get a handle of the data asset and print the URI
# ----> 4 mean_asset = ml_client.data.get(name="means-dataset", version=v1)
#       5 print(f"Data asset URI: {mean_asset.path}")
#       7 weight_asset = ml_client.data.get(name="weights-dataset", version=v1)
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/azure/ai/ml/_telemetry/activity.py:263, in monitor_with_activity.<locals>.monitor.<locals>.wrapper(*args, **kwargs)
#     260 @functools.wraps(f)
#     261 def wrapper(*args, **kwargs):
#     262     with log_activity(logger, activity_name or f.__name__, activity_type, custom_dimensions):
# --> 263         return f(*args, **kwargs)
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/azure/ai/ml/operations/_data_operations.py:224, in DataOperations.get(self, name, version, label)
#     216         msg = "Must provide either version or label."
#     217         raise ValidationException(
#     218             message=msg,
#     219             target=ErrorTarget.DATA,
#    (...)
#     222             error_type=ValidationErrorType.MISSING_FIELD,
#     223         )
# --> 224     data_version_resource = self._get(name, version)
#     225     return Data._from_rest_object(data_version_resource)
#     226 except (ValidationException, SchemaValidationError) as ex:
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/azure/ai/ml/operations/_data_operations.py:162, in DataOperations._get(self, name, version)
#     151 def _get(self, name: str, version: Optional[str] = None) -> Data:
#     152     if version:
#     153         return (
#     154             self._operation.get(
#     155                 name=name,
#     156                 version=version,
#     157                 registry_name=self._registry_name,
#     158                 **self._scope_kwargs,
#     159                 **self._init_kwargs,
#     160             )
#     161             if self._registry_name
# --> 162             else self._operation.get(
#     163                 resource_group_name=self._resource_group_name,
#     164                 workspace_name=self._workspace_name,
#     165                 name=name,
#     166                 version=version,
#     167                 **self._init_kwargs,
#     168             )
#     169         )
#     170     return (
#     171         self._container_operation.get(
#     172             name=name,
#    (...)
#     183         )
#     184     )
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/azure/core/tracing/decorator.py:76, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#      74 span_impl_type = settings.tracing_implementation()
#      75 if span_impl_type is None:
# ---> 76     return func(*args, **kwargs)
#      78 # Merge span is parameter is set, but only if no explicit parent are passed
#      79 if merge_span and not passed_in_parent:
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/azure/ai/ml/_restclient/v2022_10_01/operations/_data_versions_operations.py:479, in DataVersionsOperations.get(self, resource_group_name, workspace_name, name, version, **kwargs)
#     476 response = pipeline_response.http_response
#     478 if response.status_code not in [200]:
# --> 479     map_error(status_code=response.status_code, response=response, error_map=error_map)
#     480     error = self._deserialize.failsafe_deserialize(_models.ErrorResponse, pipeline_response)
#     481     raise HttpResponseError(response=response, model=error, error_format=ARMErrorFormat)
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/azure/core/exceptions.py:109, in map_error(status_code, response, error_map)
#     107     return
#     108 error = error_type(response=response)
# --> 109 raise error
#
# ResourceNotFoundError: (UserError) Data version means-dataset:2023.05.04.182901 (dataContainerName:version) not found.
# Code: UserError
# Message: Data version means-dataset:2023.05.04.182901 (dataContainerName:version) not found.
